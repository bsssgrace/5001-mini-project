# %% [markdown]
# # Covid VS Commodity

# %%
import requests
import pandas as pd
print(f'pandas version : {pd.__version__}')
import seaborn as sns
print(f'Seaborn version : {sns.__version__}')
import re

import matplotlib.patches as mpatches
import matplotlib as mpl
import matplotlib.dates as mdates
import datetime as dt
from matplotlib.axis import Axis
# %matplotlib inline
import matplotlib.pyplot as plt
from seaborn.rcmod import palettes
# Out:
# pandas version : 1.5.3
# Seaborn version : 0.12.2

# %% [markdown]
# ### Download data

# %%
url_energy_crude_oil_wti = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-energy-crude-oil-wti.csv'
url_energy_gasoline_natural_gas = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-energy-gasoline-natural-gas.csv'
url_energy_heat_oil = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-energy-heat-oil.csv'
url_grain_london_wheat_gbp = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-grains-london-wheat-gbp.csv'
url_grain_oats = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-grains-oats.csv'
url_grain_rough_rice = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-grains-rough-rice.csv'
url_grains_us_corn = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-grains-us-corn.csv'
url_grains_us_soybean_meal = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-grains-us-soybean-meal.csv'
url_grains_us_soybean_oil = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-grains-us-soybean-oil.csv'
url_grains_us_soybeans = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-grains-us-soybeans.csv'
url_grains_us_wheat = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-grains-us-wheat.csv'
url_meat_feeder_cattle = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-meat-feeder_cattle.csv'
url_meat_lean_hogs = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-meat-lean_hogs.csv'
url_meat_live_cattle = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-meat-live_cattle.csv'
url_energy_london_gas_oil = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-energy-london-gas-oil.csv'
url_metal_aluminum = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-metal-aluminum.csv'
url_metal_copper = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-metal-copper.csv'
url_metal_gold = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-metal-gold.csv'
url_metal_lead = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-metal-lead.csv'
url_metal_nickel = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-metal-nickel.csv'
url_metal_palladium = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-metal-palladium.csv'
url_metal_platinum = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-metal-platinum.csv'
url_metal_silver = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-metal-silver.csv'
url_metal_tin = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-metal-tin.csv'
url_metal_zinc = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-metal-zinc.csv'
url_softs_cocoa_london_gbp = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-softs-cocoa-london-gbp.csv'
url_softs_lumber = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-softs-lumber.csv'
url_softs_orange_juice = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-softs-orange-juice.csv'
url_softs_robusta_coffee_london = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-softs-robusta-coffee-london.csv'
url_softs_sugar_london = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-softs-sugar-london.csv'
url_softs_us_cocoa = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-softs-us-cocoa.csv'
url_softs_us_coffee = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-softs-us-coffee-c.csv'
url_softs_us_cotton_2 = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-softs-us-cotton-2.csv'
url_softs_us_sugar_11 = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/cfd-softs-us-sugar-11.csv'
url_covid = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/who-covid-19-global-data-updated.csv'

# %%
df1 = pd.read_csv(url_energy_crude_oil_wti)
df2 = pd.read_csv(url_energy_gasoline_natural_gas)
df3 = pd.read_csv(url_energy_heat_oil)
df4 = pd.read_csv(url_grain_london_wheat_gbp)
df5 = pd.read_csv(url_grain_oats)
df6 = pd.read_csv(url_grain_rough_rice)
df7 = pd.read_csv(url_grains_us_corn)
df8 = pd.read_csv(url_grains_us_soybean_meal)
df9 = pd.read_csv(url_grains_us_soybean_oil)
df10 = pd.read_csv(url_grains_us_soybeans)
df11 = pd.read_csv(url_grains_us_wheat)
df12 = pd.read_csv(url_meat_feeder_cattle)
df13 = pd.read_csv(url_meat_lean_hogs)
df14 = pd.read_csv(url_meat_live_cattle)
df15 = pd.read_csv(url_energy_london_gas_oil)
df16 = pd.read_csv(url_metal_aluminum)
df17 = pd.read_csv(url_metal_copper)
df18 = pd.read_csv(url_metal_gold)
df19 = pd.read_csv(url_metal_lead)
df20 = pd.read_csv(url_metal_nickel)
df21 = pd.read_csv(url_metal_palladium)
df22 = pd.read_csv(url_metal_platinum)
df23 = pd.read_csv(url_metal_silver)
df24 = pd.read_csv(url_metal_tin)
df25 = pd.read_csv(url_metal_zinc)
df26 = pd.read_csv(url_softs_cocoa_london_gbp)
df27 = pd.read_csv(url_softs_lumber)
df28 = pd.read_csv(url_softs_orange_juice)
df29 = pd.read_csv(url_softs_robusta_coffee_london)
df30 = pd.read_csv(url_softs_sugar_london)
df31 = pd.read_csv(url_softs_us_cocoa)
df32 = pd.read_csv(url_softs_us_coffee)
df33 = pd.read_csv(url_softs_us_cotton_2)
df34 = pd.read_csv(url_softs_us_sugar_11)

# %% [markdown]
# ### Prepare data

# %%
# Add 4 other columns along with its required data into each dataframe (Required data is Type of commodity, Commodity name, Curreny and Normalized price of each commodity)
from pandas.io.formats.format import DataFrameFormatter
dataframes = [
    [df1,'Energy','Crude Oil','USD'],
    [df2,'Energy','Natural Gas','USD'],
    [df3,'Energy','Heat Oil','USD'],
    [df4,'Grain','Wheat','GBP'],
    [df5,'Grain','Oats','USD'],
    [df6,'Grain','Rough Rice','USD'],
    [df7,'Grain','Corn','USD'],
    [df8,'Grain','Soy Bean Meal','USD'],
    [df9,'Grain','Soy Bean Oil','USD'],
    [df10,'Grain','Soy Beans','USD'],
    [df11,'Grain','Wheat','USD'],
    [df12,'Meat','Feeder Cattle','USD'],
    [df13,'Meat','Lean Hogs','USD'],
    [df14,'Meat','Live Cattle','USD'],
    [df15,'Energy','Gas Oil','USD'],
    [df16,'Metal','Aluminum','USD'],
    [df17,'Metal','Copper','USD'],
    [df18,'Metal','Gold','USD'],
    [df19,'Metal','Lead','USD'],
    [df20,'Metal','Nickel','USD'],
    [df21,'Metal','Palladium','USD'],
    [df22,'Metal','Platinum','USD'],
    [df23,'Metal','Silver','USD'],
    [df24,'Metal','Tin','USD'],
    [df25,'Metal','Zinc','USD'],
    [df26,'Softs','Cocoa','GBP'],
    [df27,'Softs','Lumber','USD'],
    [df28,'Softs','Orange Juice','USD'],
    [df29,'Softs','Robusta Coffee','USD'],
    [df30,'Softs','Sugar','USD'],
    [df31,'Softs','Cocoa','USD'],
    [df32,'Softs','Coffee','USD'],
    [df33,'Softs','Cotton2','USD'],
    [df34,'Softs','Sugar11','USD']
]

for i in range(len(dataframes)):
    dataframes[i][0]['Type'] = dataframes[i][1]
    dataframes[i][0]['Commodity'] = dataframes[i][2]
    dataframes[i][0]['Currency'] = dataframes[i][3]
    dataframes[i][0]['Date'] = pd.to_datetime(dataframes[i][0]['Date'])
    #Normalize the prices so that they can be compared against each other
    dataframes[i][0]['Norm_price'] = (dataframes[i][0]['Price'] - dataframes[i][0]['Price'].min())  / (dataframes[i][0]['Price'].max() - dataframes[i][0]['Price'].min())
    #dataframes[i][0] = dataframes[i][0].rename(columns = {'Price':'P_' + dataframes[i][2]})
    #display(dataframes[i][0])
display(df1)
print(df1['Norm_price'].max())
print(df1['Norm_price'].min())
# Out:
#           Date  Price   Open   High    Low       Vol.  Change %    Type  \
# 0   2023-06-16  71.78  70.55  71.89  69.95        NaN    0.0164  Energy
# 1   2023-06-15  70.62  68.70  70.96  67.97   115610.0    0.0344  Energy
# 2   2023-06-14  68.27  69.35  70.49  68.07   304450.0   -0.0166  Energy
# 3   2023-06-13  69.42  67.31  69.83  67.15   366350.0    0.0343  Energy
# 4   2023-06-12  67.12  70.27  70.33  66.80   404770.0   -0.0435  Energy
# ..         ...    ...    ...    ...    ...        ...       ...     ...
# 909 2020-01-09  59.56  59.99  60.31  58.66   750930.0   -0.0008  Energy
# 910 2020-01-08  59.61  62.84  65.65  59.15  1210000.0   -0.0493  Energy
# 911 2020-01-07  62.70  62.91  63.15  62.11   582650.0   -0.0090  Energy
# 912 2020-01-06  63.27  63.71  64.72  62.64   724240.0    0.0035  Energy
# 913 2020-01-03  63.05  61.18  64.09  61.13   885860.0    0.0306  Energy
#
#      Commodity Currency  Norm_price
# 0    Crude Oil      USD    0.678175
# 1    Crude Oil      USD    0.670985
# 2    Crude Oil      USD    0.656419
# 3    Crude Oil      USD    0.663547
# 4    Crude Oil      USD    0.649290
# ..         ...      ...         ...
# 909  Crude Oil      USD    0.602430
# 910  Crude Oil      USD    0.602740
# 911  Crude Oil      USD    0.621893
# 912  Crude Oil      USD    0.625426
# 913  Crude Oil      USD    0.624062
#
# [914 rows x 11 columns]
# 1.0
# 0.0

# %%
#Merge all commodities to one data frame
df_all = pd.DataFrame()
for i in range(len(dataframes)):
    df_all = pd.concat([df_all, dataframes[i][0]])

#Select only interested columns
df_all = df_all.loc[:,['Date','Price','Vol.','Change %', 'Type', 'Commodity', 'Currency']]

#df_all['Price'] = pd.to_numeric(df_all['Price'], errors = 'coerce')

#Check Merged Data Frame
df_all.info()
#display(df_all)

#Check for NaN
df_all.loc[df_all['Price'].isna(), ['Commodity','Price']].groupby('Commodity').transform('sum')
#df_all['Price'].isna().sum()
df_Null = df_all['Price'].isnull().groupby(df_all['Commodity']).sum().astype(int).reset_index(name='count')
display(df_Null)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29547 entries, 0 to 870
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       29547 non-null  datetime64[ns]
#  1   Price      29547 non-null  float64
#  2   Vol.       26283 non-null  float64
#  3   Change %   29547 non-null  float64
#  4   Type       29547 non-null  object
#  5   Commodity  29547 non-null  object
#  6   Currency   29547 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 1.8+ MB
#          Commodity  count
# 0         Aluminum      0
# 1            Cocoa      0
# 2           Coffee      0
# 3           Copper      0
# 4             Corn      0
# 5          Cotton2      0
# 6        Crude Oil      0
# 7    Feeder Cattle      0
# 8          Gas Oil      0
# 9             Gold      0
# 10        Heat Oil      0
# 11            Lead      0
# 12       Lean Hogs      0
# 13     Live Cattle      0
# 14          Lumber      0
# 15     Natural Gas      0
# 16          Nickel      0
# 17            Oats      0
# 18    Orange Juice      0
# 19       Palladium      0
# 20        Platinum      0
# 21  Robusta Coffee      0
# 22      Rough Rice      0
# 23          Silver      0
# 24   Soy Bean Meal      0
# 25    Soy Bean Oil      0
# 26       Soy Beans      0
# 27           Sugar      0
# 28         Sugar11      0
# 29             Tin      0
# 30           Wheat      0
# 31            Zinc      0

# %%
#Check info for each data frame
for i in range(len(dataframes)):
    print(dataframes[i][2])
    dataframes[i][0].info()
# Out:
# Crude Oil
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 914 entries, 0 to 913
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        914 non-null    datetime64[ns]
#  1   Price       914 non-null    float64
#  2   Open        914 non-null    float64
#  3   High        914 non-null    float64
#  4   Low         914 non-null    float64
#  5   Vol.        847 non-null    float64
#  6   Change %    914 non-null    float64
#  7   Type        914 non-null    object
#  8   Commodity   914 non-null    object
#  9   Currency    914 non-null    object
#  10  Norm_price  914 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 78.7+ KB
# Natural Gas
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        912 non-null    datetime64[ns]
#  1   Price       912 non-null    float64
#  2   Open        912 non-null    float64
#  3   High        912 non-null    float64
#  4   Low         912 non-null    float64
#  5   Vol.        866 non-null    float64
#  6   Change %    912 non-null    float64
#  7   Type        912 non-null    object
#  8   Commodity   912 non-null    object
#  9   Currency    912 non-null    object
#  10  Norm_price  912 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 78.5+ KB
# Heat Oil
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 911 entries, 0 to 910
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        911 non-null    datetime64[ns]
#  1   Price       911 non-null    float64
#  2   Open        911 non-null    float64
#  3   High        911 non-null    float64
#  4   Low         911 non-null    float64
#  5   Vol.        870 non-null    float64
#  6   Change %    911 non-null    float64
#  7   Type        911 non-null    object
#  8   Commodity   911 non-null    object
#  9   Currency    911 non-null    object
#  10  Norm_price  911 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 78.4+ KB
# Wheat
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        870 non-null    datetime64[ns]
#  1   Price       870 non-null    float64
#  2   Open        870 non-null    float64
#  3   High        870 non-null    float64
#  4   Low         870 non-null    float64
#  5   Vol.        400 non-null    float64
#  6   Change %    870 non-null    float64
#  7   Type        870 non-null    object
#  8   Commodity   870 non-null    object
#  9   Currency    870 non-null    object
#  10  Norm_price  870 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 74.9+ KB
# Oats
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 873 entries, 0 to 872
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        873 non-null    datetime64[ns]
#  1   Price       873 non-null    float64
#  2   Open        873 non-null    float64
#  3   High        873 non-null    float64
#  4   Low         873 non-null    float64
#  5   Vol.        762 non-null    float64
#  6   Change %    873 non-null    float64
#  7   Type        873 non-null    object
#  8   Commodity   873 non-null    object
#  9   Currency    873 non-null    object
#  10  Norm_price  873 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 75.1+ KB
# Rough Rice
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 875 entries, 0 to 874
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        875 non-null    datetime64[ns]
#  1   Price       875 non-null    float64
#  2   Open        875 non-null    float64
#  3   High        875 non-null    float64
#  4   Low         875 non-null    float64
#  5   Vol.        800 non-null    float64
#  6   Change %    875 non-null    float64
#  7   Type        875 non-null    object
#  8   Commodity   875 non-null    object
#  9   Currency    875 non-null    object
#  10  Norm_price  875 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 75.3+ KB
# Corn
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        883 non-null    datetime64[ns]
#  1   Price       883 non-null    float64
#  2   Open        883 non-null    float64
#  3   High        883 non-null    float64
#  4   Low         883 non-null    float64
#  5   Vol.        867 non-null    float64
#  6   Change %    883 non-null    float64
#  7   Type        883 non-null    object
#  8   Commodity   883 non-null    object
#  9   Currency    883 non-null    object
#  10  Norm_price  883 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 76.0+ KB
# Soy Bean Meal
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        891 non-null    datetime64[ns]
#  1   Price       891 non-null    float64
#  2   Open        891 non-null    float64
#  3   High        891 non-null    float64
#  4   Low         891 non-null    float64
#  5   Vol.        844 non-null    float64
#  6   Change %    891 non-null    float64
#  7   Type        891 non-null    object
#  8   Commodity   891 non-null    object
#  9   Currency    891 non-null    object
#  10  Norm_price  891 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 76.7+ KB
# Soy Bean Oil
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 895 entries, 0 to 894
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        895 non-null    datetime64[ns]
#  1   Price       895 non-null    float64
#  2   Open        895 non-null    float64
#  3   High        895 non-null    float64
#  4   Low         895 non-null    float64
#  5   Vol.        850 non-null    float64
#  6   Change %    895 non-null    float64
#  7   Type        895 non-null    object
#  8   Commodity   895 non-null    object
#  9   Currency    895 non-null    object
#  10  Norm_price  895 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 77.0+ KB
# Soy Beans
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        892 non-null    datetime64[ns]
#  1   Price       892 non-null    float64
#  2   Open        892 non-null    float64
#  3   High        892 non-null    float64
#  4   Low         892 non-null    float64
#  5   Vol.        634 non-null    float64
#  6   Change %    892 non-null    float64
#  7   Type        892 non-null    object
#  8   Commodity   892 non-null    object
#  9   Currency    892 non-null    object
#  10  Norm_price  892 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 76.8+ KB
# Wheat
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        896 non-null    datetime64[ns]
#  1   Price       896 non-null    float64
#  2   Open        896 non-null    float64
#  3   High        896 non-null    float64
#  4   Low         896 non-null    float64
#  5   Vol.        720 non-null    float64
#  6   Change %    896 non-null    float64
#  7   Type        896 non-null    object
#  8   Commodity   896 non-null    object
#  9   Currency    896 non-null    object
#  10  Norm_price  896 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 77.1+ KB
# Feeder Cattle
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 884 entries, 0 to 883
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        884 non-null    datetime64[ns]
#  1   Price       884 non-null    float64
#  2   Open        884 non-null    float64
#  3   High        884 non-null    float64
#  4   Low         884 non-null    float64
#  5   Vol.        870 non-null    float64
#  6   Change %    884 non-null    float64
#  7   Type        884 non-null    object
#  8   Commodity   884 non-null    object
#  9   Currency    884 non-null    object
#  10  Norm_price  884 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 76.1+ KB
# Lean Hogs
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 876 entries, 0 to 875
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        876 non-null    datetime64[ns]
#  1   Price       876 non-null    float64
#  2   Open        876 non-null    float64
#  3   High        876 non-null    float64
#  4   Low         876 non-null    float64
#  5   Vol.        863 non-null    float64
#  6   Change %    876 non-null    float64
#  7   Type        876 non-null    object
#  8   Commodity   876 non-null    object
#  9   Currency    876 non-null    object
#  10  Norm_price  876 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 75.4+ KB
# Live Cattle
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 884 entries, 0 to 883
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        884 non-null    datetime64[ns]
#  1   Price       884 non-null    float64
#  2   Open        884 non-null    float64
#  3   High        884 non-null    float64
#  4   Low         884 non-null    float64
#  5   Vol.        870 non-null    float64
#  6   Change %    884 non-null    float64
#  7   Type        884 non-null    object
#  8   Commodity   884 non-null    object
#  9   Currency    884 non-null    object
#  10  Norm_price  884 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 76.1+ KB
# Gas Oil
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        893 non-null    datetime64[ns]
#  1   Price       893 non-null    float64
#  2   Open        893 non-null    float64
#  3   High        893 non-null    float64
#  4   Low         893 non-null    float64
#  5   Vol.        892 non-null    float64
#  6   Change %    893 non-null    float64
#  7   Type        893 non-null    object
#  8   Commodity   893 non-null    object
#  9   Currency    893 non-null    object
#  10  Norm_price  893 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 76.9+ KB
# Aluminum
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 871 entries, 0 to 870
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        871 non-null    datetime64[ns]
#  1   Price       871 non-null    float64
#  2   Open        871 non-null    float64
#  3   High        871 non-null    float64
#  4   Low         871 non-null    float64
#  5   Vol.        852 non-null    float64
#  6   Change %    871 non-null    float64
#  7   Type        871 non-null    object
#  8   Commodity   871 non-null    object
#  9   Currency    871 non-null    object
#  10  Norm_price  871 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 75.0+ KB
# Copper
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        915 non-null    datetime64[ns]
#  1   Price       915 non-null    float64
#  2   Open        915 non-null    float64
#  3   High        915 non-null    float64
#  4   Low         915 non-null    float64
#  5   Vol.        862 non-null    float64
#  6   Change %    915 non-null    float64
#  7   Type        915 non-null    object
#  8   Commodity   915 non-null    object
#  9   Currency    915 non-null    object
#  10  Norm_price  915 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 78.8+ KB
# Gold
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        110 non-null    datetime64[ns]
#  1   Price       110 non-null    float64
#  2   Open        110 non-null    float64
#  3   High        110 non-null    float64
#  4   Low         110 non-null    float64
#  5   Vol.        101 non-null    float64
#  6   Change %    110 non-null    float64
#  7   Type        110 non-null    object
#  8   Commodity   110 non-null    object
#  9   Currency    110 non-null    object
#  10  Norm_price  110 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 9.6+ KB
# Lead
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        870 non-null    datetime64[ns]
#  1   Price       870 non-null    float64
#  2   Open        870 non-null    float64
#  3   High        870 non-null    float64
#  4   Low         870 non-null    float64
#  5   Vol.        870 non-null    int64
#  6   Change %    870 non-null    float64
#  7   Type        870 non-null    object
#  8   Commodity   870 non-null    object
#  9   Currency    870 non-null    object
#  10  Norm_price  870 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(3)
# memory usage: 74.9+ KB
# Nickel
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868 entries, 0 to 867
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        868 non-null    datetime64[ns]
#  1   Price       868 non-null    float64
#  2   Open        868 non-null    float64
#  3   High        868 non-null    float64
#  4   Low         868 non-null    float64
#  5   Vol.        842 non-null    float64
#  6   Change %    868 non-null    float64
#  7   Type        868 non-null    object
#  8   Commodity   868 non-null    object
#  9   Currency    868 non-null    object
#  10  Norm_price  868 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 74.7+ KB
# Palladium
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1042 non-null   datetime64[ns]
#  1   Price       1042 non-null   float64
#  2   Open        1042 non-null   float64
#  3   High        1042 non-null   float64
#  4   Low         1042 non-null   float64
#  5   Vol.        87 non-null     float64
#  6   Change %    1042 non-null   float64
#  7   Type        1042 non-null   object
#  8   Commodity   1042 non-null   object
#  9   Currency    1042 non-null   object
#  10  Norm_price  1042 non-null   float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 89.7+ KB
# Platinum
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1073 entries, 0 to 1072
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1073 non-null   datetime64[ns]
#  1   Price       1073 non-null   float64
#  2   Open        1073 non-null   float64
#  3   High        1073 non-null   float64
#  4   Low         1073 non-null   float64
#  5   Vol.        591 non-null    float64
#  6   Change %    1073 non-null   float64
#  7   Type        1073 non-null   object
#  8   Commodity   1073 non-null   object
#  9   Currency    1073 non-null   object
#  10  Norm_price  1073 non-null   float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 92.3+ KB
# Silver
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 882 entries, 0 to 881
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        882 non-null    datetime64[ns]
#  1   Price       882 non-null    float64
#  2   Open        882 non-null    float64
#  3   High        882 non-null    float64
#  4   Low         882 non-null    float64
#  5   Vol.        849 non-null    float64
#  6   Change %    882 non-null    float64
#  7   Type        882 non-null    object
#  8   Commodity   882 non-null    object
#  9   Currency    882 non-null    object
#  10  Norm_price  882 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 75.9+ KB
# Tin
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        870 non-null    datetime64[ns]
#  1   Price       870 non-null    int64
#  2   Open        870 non-null    float64
#  3   High        870 non-null    float64
#  4   Low         870 non-null    float64
#  5   Vol.        870 non-null    int64
#  6   Change %    870 non-null    float64
#  7   Type        870 non-null    object
#  8   Commodity   870 non-null    object
#  9   Currency    870 non-null    object
#  10  Norm_price  870 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(3)
# memory usage: 74.9+ KB
# Zinc
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 871 entries, 0 to 870
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        871 non-null    datetime64[ns]
#  1   Price       871 non-null    float64
#  2   Open        871 non-null    float64
#  3   High        871 non-null    float64
#  4   Low         871 non-null    float64
#  5   Vol.        854 non-null    float64
#  6   Change %    871 non-null    float64
#  7   Type        871 non-null    object
#  8   Commodity   871 non-null    object
#  9   Currency    871 non-null    object
#  10  Norm_price  871 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 75.0+ KB
# Cocoa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        870 non-null    datetime64[ns]
#  1   Price       870 non-null    int64
#  2   Open        870 non-null    int64
#  3   High        870 non-null    int64
#  4   Low         870 non-null    int64
#  5   Vol.        864 non-null    float64
#  6   Change %    870 non-null    float64
#  7   Type        870 non-null    object
#  8   Commodity   870 non-null    object
#  9   Currency    870 non-null    object
#  10  Norm_price  870 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(3)
# memory usage: 74.9+ KB
# Lumber
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        863 non-null    datetime64[ns]
#  1   Price       863 non-null    float64
#  2   Open        863 non-null    float64
#  3   High        863 non-null    float64
#  4   Low         863 non-null    float64
#  5   Vol.        843 non-null    float64
#  6   Change %    863 non-null    float64
#  7   Type        863 non-null    object
#  8   Commodity   863 non-null    object
#  9   Currency    863 non-null    object
#  10  Norm_price  863 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 74.3+ KB
# Orange Juice
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 869 entries, 0 to 868
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        869 non-null    datetime64[ns]
#  1   Price       869 non-null    float64
#  2   Open        869 non-null    float64
#  3   High        869 non-null    float64
#  4   Low         869 non-null    float64
#  5   Vol.        770 non-null    float64
#  6   Change %    869 non-null    float64
#  7   Type        869 non-null    object
#  8   Commodity   869 non-null    object
#  9   Currency    869 non-null    object
#  10  Norm_price  869 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 74.8+ KB
# Robusta Coffee
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        870 non-null    datetime64[ns]
#  1   Price       870 non-null    int64
#  2   Open        870 non-null    int64
#  3   High        870 non-null    int64
#  4   Low         870 non-null    int64
#  5   Vol.        855 non-null    float64
#  6   Change %    870 non-null    float64
#  7   Type        870 non-null    object
#  8   Commodity   870 non-null    object
#  9   Currency    870 non-null    object
#  10  Norm_price  870 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(3)
# memory usage: 74.9+ KB
# Sugar
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        870 non-null    datetime64[ns]
#  1   Price       870 non-null    float64
#  2   Open        870 non-null    float64
#  3   High        870 non-null    float64
#  4   Low         870 non-null    float64
#  5   Vol.        870 non-null    int64
#  6   Change %    870 non-null    float64
#  7   Type        870 non-null    object
#  8   Commodity   870 non-null    object
#  9   Currency    870 non-null    object
#  10  Norm_price  870 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(3)
# memory usage: 74.9+ KB
# Cocoa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        870 non-null    datetime64[ns]
#  1   Price       870 non-null    int64
#  2   Open        870 non-null    int64
#  3   High        870 non-null    int64
#  4   Low         870 non-null    int64
#  5   Vol.        863 non-null    float64
#  6   Change %    870 non-null    float64
#  7   Type        870 non-null    object
#  8   Commodity   870 non-null    object
#  9   Currency    870 non-null    object
#  10  Norm_price  870 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(3)
# memory usage: 74.9+ KB
# Coffee
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        870 non-null    datetime64[ns]
#  1   Price       870 non-null    float64
#  2   Open        870 non-null    float64
#  3   High        870 non-null    float64
#  4   Low         870 non-null    float64
#  5   Vol.        857 non-null    float64
#  6   Change %    870 non-null    float64
#  7   Type        870 non-null    object
#  8   Commodity   870 non-null    object
#  9   Currency    870 non-null    object
#  10  Norm_price  870 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 74.9+ KB
# Cotton2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 873 entries, 0 to 872
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        873 non-null    datetime64[ns]
#  1   Price       873 non-null    float64
#  2   Open        873 non-null    float64
#  3   High        873 non-null    float64
#  4   Low         873 non-null    float64
#  5   Vol.        761 non-null    float64
#  6   Change %    873 non-null    float64
#  7   Type        873 non-null    object
#  8   Commodity   873 non-null    object
#  9   Currency    873 non-null    object
#  10  Norm_price  873 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 75.1+ KB
# Sugar11
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 871 entries, 0 to 870
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        871 non-null    datetime64[ns]
#  1   Price       871 non-null    float64
#  2   Open        871 non-null    float64
#  3   High        871 non-null    float64
#  4   Low         871 non-null    float64
#  5   Vol.        867 non-null    float64
#  6   Change %    871 non-null    float64
#  7   Type        871 non-null    object
#  8   Commodity   871 non-null    object
#  9   Currency    871 non-null    object
#  10  Norm_price  871 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 75.0+ KB

# %%
# Prepare additional data for global new Covid cases
url_global_new_case = 'https://raw.githubusercontent.com/bsssgrace/5001-mini-project/main/global-daily-new-cases.csv'
df36 = pd.read_csv(url_global_new_case)
df36['Date_reported'] = pd.to_datetime(df36['Date_reported'])
#df36['Date_reported'] = df36['Date_reported'].dt.strftime('%Y-%m-%d')
df36.info()
print(df36['New_cases'].min())
print(df36['New_cases'].max())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date_reported  1259 non-null   datetime64[ns]
#  1   New_cases      1259 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 19.8 KB
# 0
# 7945883

# %%
# Check data info
display(df36)
df36.info()
# Out:
#      Date_reported  New_cases
# 0       2020-01-03          0
# 1       2020-01-04          3
# 2       2020-01-05          0
# 3       2020-01-06          3
# 4       2020-01-07          0
# ...            ...        ...
# 1254    2023-06-10      31083
# 1255    2023-06-11      59592
# 1256    2023-06-12      28034
# 1257    2023-06-13     106686
# 1258    2023-06-14          0
#
# [1259 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date_reported  1259 non-null   datetime64[ns]
#  1   New_cases      1259 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 19.8 KB

# %% [markdown]
# ### Plot charts

# %%
print("Energy")
df_energy = pd.DataFrame()
for i in range(len(dataframes)):
    if dataframes[i][1] == 'Energy':
      df_energy = pd.concat([df_energy, dataframes[i][0]])

plt.figure(figsize = [15,7])
plt.suptitle('Energy Price VS Covid situation', size = 15, y=0.92)
ax1 = sns.lineplot(
        x='Date',
        y='Norm_price',
        data=df_energy,
        sort=True,
        color='blue',
        palette="Paired",
        hue='Commodity',
        legend = 'full'
)
ax1.set_ylabel('Normalized Price Index')
#ax1.set_ylim(-50, 150)
#ax1_patch = mpatches.Patch(color='blue', label='Price')
#ax1.legend(handles=[ax1_patch], loc="upper left")
# set up the 2nd axis
ax2 = ax1.twinx()
# plot bar chart on axis #2
ax2 = sns.lineplot(
        x='Date_reported',
        y='New_cases',
        data=df36,
        color='black',
        sort=True,
        alpha=1,
        ax = ax2       # Pre-existing axes for the plot
    )
ax2.grid(False) # turn off grid #2
ax2.set_ylabel('Global new \nCovid case')
#ax2.set_ylim(-0.1, 0.1)
ax2_patch = mpatches.Patch(color='black', label='Global new \nCovid case')
ax2.legend(handles=[ax2_patch], loc="upper right")

ax1.axvspan(*mdates.datestr2num(['2020-03-01', '2020-07-01']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2020-05-03']), 0.8, "Start of Pendemic",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['10/01/2020', '10/01/2021']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2021-04-01']), 0.95, "Quanrantine Lifting and Reimplementing",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['11/24/2021', '05/01/2022']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-02-10']), 0.95, "Borders Opening",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['06/01/2022', '09/01/2022']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-07-15']), 0.95, "Tourism and\n Entertainment\n Ban Lifting",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['11/01/2022', '02/01/2023']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-11-15']), 0.95, "China\n Reveal",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

locator = mdates.MonthLocator()
Axis.set_major_locator(ax1.xaxis,locator)
plt.setp(ax1.get_xticklabels(), rotation = 45, horizontalalignment='center')
plt.xticks(fontsize = 5)
#plt.yticks(fontsize = 5)
plt.ylabel('New Cases in million')
plt.yscale('linear')
plt.xlim(*mdates.datestr2num(['2020-01-01', '2023-06-25']))
ax1.legend(fontsize=10, loc="upper left")
plt.show()
# Out:
# Energy

# %%
print("Meat")
df_meat = pd.DataFrame()
for i in range(len(dataframes)):
    if dataframes[i][1] == 'Meat':
      df_meat = pd.concat([df_meat, dataframes[i][0]])

plt.figure(figsize = [15,7])
plt.suptitle('Meat VS Covid situation', size = 15, y=0.92)
ax1 = sns.lineplot(
        x='Date',
        y='Norm_price',
        data=df_meat,
        sort=True,
        palette="flare",
        hue='Commodity',
        legend = 'full'
)
ax1.set_ylabel('Normalized Price Index')
#ax1.set_ylim(-50, 150)
#ax1_patch = mpatches.Patch(color='blue', label='Price')
#ax1.legend(handles=[ax1_patch], loc="upper left")
# set up the 2nd axis
ax2 = ax1.twinx()
# plot bar chart on axis #2
ax2 = sns.lineplot(
        x='Date_reported',
        y='New_cases',
        data=df36,
        color='black',
        sort=True,
        alpha=1,
        #legend = 'full',
        ax = ax2       # Pre-existing axes for the plot
    )
ax2.grid(False) # turn off grid #2
ax2.set_ylabel('Global new \nCovid case')
#ax2.set_ylim(-0.1, 0.1)
ax2_patch = mpatches.Patch(color='black', label='Global new \nCovid case')
ax2.legend(handles=[ax2_patch], loc="upper right")

ax1.axvspan(*mdates.datestr2num(['2020-03-01', '2020-07-01']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2020-05-03']), 0.8, "Start of Pendemic",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['10/01/2020', '10/01/2021']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2021-04-01']), 0.8, "Quanrantine Lifting and Reimplementing",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['11/24/2021', '05/01/2022']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-02-10']), 0.8, "Borders Opening",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['06/01/2022', '09/01/2022']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-07-15']), 0.8, "Tourism and\n Entertainment\n Ban Lifting",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['11/01/2022', '02/01/2023']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-11-15']), 0.95, "China\n Reveal",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

locator = mdates.MonthLocator()
Axis.set_major_locator(ax1.xaxis,locator)
plt.setp(ax1.get_xticklabels(), rotation = 45, horizontalalignment='center')
plt.xticks(fontsize = 5)
#plt.yticks(fontsize = 5)
plt.ylabel('New Cases in million')
plt.yscale('linear')
plt.xlim(*mdates.datestr2num(['2020-01-01', '2023-06-25']))
ax1.legend(fontsize=10, loc="upper left")
plt.show()
# Out:
# Meat

# %%
print("Grain")
df_grain = pd.DataFrame()
for i in range(len(dataframes)):
    if dataframes[i][1] == 'Grain':
      df_grain = pd.concat([df_grain, dataframes[i][0]])

plt.figure(figsize = [15,7])
plt.suptitle('Grain Price VS Covid situation', size = 15, y=0.92)
ax1 = sns.lineplot(
        x='Date',
        y='Norm_price',
        data=df_grain,
        sort=True,
        color='blue',
        palette="Paired",
        hue='Commodity',
        legend = 'full'
)
ax1.set_ylabel('Normalized Price Index')
#ax1.set_ylim(-50, 150)
#ax1_patch = mpatches.Patch(color='blue', label='Price')
#ax1.legend(handles=[ax1_patch], loc="upper left")
# set up the 2nd axis
ax2 = ax1.twinx()
# plot bar chart on axis #2
ax2 = sns.lineplot(
        x='Date_reported',
        y='New_cases',
        data=df36,
        color='black',
        sort=True,
        alpha=1,
        ax = ax2       # Pre-existing axes for the plot
    )
ax2.grid(False) # turn off grid #2
ax2.set_ylabel('Global new \nCovid case')
#ax2.set_ylim(-0.1, 0.1)
ax2_patch = mpatches.Patch(color='black', label='Global new \nCovid case')
ax2.legend(handles=[ax2_patch], loc="upper right")

ax1.axvspan(*mdates.datestr2num(['2020-03-01', '2020-07-01']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2020-05-03']), 0.6, "Start of Pendemic",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['10/01/2020', '10/01/2021']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2021-04-01']), 0.95, "Quanrantine Lifting and Reimplementing",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['11/24/2021', '05/01/2022']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-02-10']), 0.95, "Borders Opening",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['06/01/2022', '09/01/2022']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-07-15']), 0.95, "Tourism and\n Entertainment\n Ban Lifting",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['11/01/2022', '02/01/2023']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-11-15']), 0.95, "China\n Reveal",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

locator = mdates.MonthLocator()
Axis.set_major_locator(ax1.xaxis,locator)
plt.setp(ax1.get_xticklabels(), rotation = 45, horizontalalignment='center')
plt.xticks(fontsize = 5)
#plt.yticks(fontsize = 5)
plt.ylabel('New Cases in million')
plt.yscale('linear')
plt.xlim(*mdates.datestr2num(['2020-01-01', '2023-06-25']))
ax1.legend(fontsize=10, loc="upper left")
plt.show()
# Out:
# Grain

# %%
print("Metal")
df_metal = pd.DataFrame()
for i in range(len(dataframes)):
    if dataframes[i][1] == 'Metal':
      df_metal = pd.concat([df_metal, dataframes[i][0]])

plt.figure(figsize = [15,7])
plt.suptitle('Metal Price VS Covid situation', size = 15, y=0.92)
ax1 = sns.lineplot(
        x='Date',
        y='Norm_price',
        data=df_metal,
        sort=True,
        color='blue',
        palette="Paired",
        hue='Commodity',
        legend = 'full'
)
ax1.set_ylabel('Normalized Price Index')
#ax1.set_ylim(-50, 150)
#ax1_patch = mpatches.Patch(color='blue', label='Price')
#x1.legend(handles=[ax1_patch], loc="upper left")
# set up the 2nd axis
ax2 = ax1.twinx()
# plot bar chart on axis #2
ax2 = sns.lineplot(
        x='Date_reported',
        y='New_cases',
        data=df36,
        color='black',
        sort=True,
        alpha=1,
        ax = ax2       # Pre-existing axes for the plot
    )
ax2.grid(False) # turn off grid #2
ax2.set_ylabel('Global new \nCovid case')
#ax2.set_ylim(-0.1, 0.1)
ax2_patch = mpatches.Patch(color='black', label='Global new \nCovid case')
ax2.legend(handles=[ax2_patch], loc="upper right")

ax1.axvspan(*mdates.datestr2num(['2020-03-01', '2020-07-01']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2020-05-03']), 0.5, "Start of Pendemic",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['10/01/2020', '10/01/2021']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2021-04-01']), 0.95, "Quanrantine Lifting and Reimplementing",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['11/24/2021', '05/01/2022']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-02-10']), 0.95, "Borders Opening",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['06/01/2022', '09/01/2022']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-07-15']), 0.95, "Tourism and\n Entertainment\n Ban Lifting",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['11/01/2022', '02/01/2023']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-11-15']), 0.95, "China\n Reveal",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

locator = mdates.MonthLocator()
Axis.set_major_locator(ax1.xaxis,locator)
plt.setp(ax1.get_xticklabels(), rotation = 45, horizontalalignment='center')
plt.xticks(fontsize = 5)
#plt.yticks(fontsize = 5)
plt.ylabel('New Cases in million')
plt.yscale('linear')
plt.xlim(*mdates.datestr2num(['2020-01-01', '2023-06-25']))
ax1.legend(fontsize=10, loc="upper left")
plt.show()
# Out:
# Metal

# %%
print("Softs")
df_softs = pd.DataFrame()
for i in range(len(dataframes)):
    if dataframes[i][1] == 'Softs':
      df_softs = pd.concat([df_softs, dataframes[i][0]])

plt.figure(figsize = [15,7])
plt.suptitle('Softs Price VS Covid situation', size = 15, y=0.92)
ax1 = sns.lineplot(
        x='Date',
        y='Norm_price',
        data=df_softs,
        sort=True,
        color='blue',
        palette="Paired",
        hue='Commodity',
        legend = 'full'
)
ax1.set_ylabel('Normalized Price Index')
#ax1.set_ylim(-50, 150)
#ax1_patch = mpatches.Patch(color='blue', label='Price')
#ax1.legend(handles=[ax1_patch], loc="upper left")
# set up the 2nd axis
ax2 = ax1.twinx()
# plot bar chart on axis #2
ax2 = sns.lineplot(
        x='Date_reported',
        y='New_cases',
        data=df36,
        color='black',
        sort=True,
        alpha=1,
        ax = ax2       # Pre-existing axes for the plot
    )
ax2.grid(False) # turn off grid #2
ax2.set_ylabel('Global new \nCovid case')
#ax2.set_ylim(-0.1, 0.1)
ax2_patch = mpatches.Patch(color='black', label='Global new \nCovid case')
ax2.legend(handles=[ax2_patch], loc="upper right")

ax1.axvspan(*mdates.datestr2num(['2020-03-01', '2020-07-01']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2020-05-03']), 0.6, "Start of Pendemic",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['10/01/2020', '10/01/2021']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2021-04-01']), 0.95, "Quanrantine Lifting and Reimplementing",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['11/24/2021', '05/01/2022']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-02-10']), 0.95, "Borders Opening",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['06/01/2022', '09/01/2022']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-07-15']), 0.95, "Tourism and\n Entertainment\n Ban Lifting",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

ax1.axvspan(*mdates.datestr2num(['11/01/2022', '02/01/2023']), color="red", alpha=0.1)
ax1.text(*mdates.datestr2num(['2022-11-15']), 0.95, "China\n Reveal",
       fontsize = 10,          # Size
       fontstyle = "oblique",  # Style
       color = "black",          # Color
       ha = "center", # Horizontal alignment
       va = "center") # Vertical alignment

locator = mdates.MonthLocator()
Axis.set_major_locator(ax1.xaxis,locator)
plt.setp(ax1.get_xticklabels(), rotation = 45, horizontalalignment='center')
plt.xticks(fontsize = 5)
#plt.yticks(fontsize = 5)
plt.ylabel('New Cases in million')
plt.yscale('linear')
plt.xlim(*mdates.datestr2num(['2020-01-01', '2023-06-25']))
ax1.legend(fontsize=10, loc="upper left")
plt.show()
# Out:
# Softs
